# %% [markdown]
# >[Prepration](#updateTitle=true&folderId=1ItfGk4B7y8TZqsIqknrRk98yg4h93nrI&scrollTo=a1VIQheeh3Lq)
#
# >[Descriptive statistical analysis](#updateTitle=true&folderId=1ItfGk4B7y8TZqsIqknrRk98yg4h93nrI&scrollTo=Bnd2NYfkiLaQ)
#
# >[Plotting of sheets' means and standard devs](#updateTitle=true&folderId=1ItfGk4B7y8TZqsIqknrRk98yg4h93nrI&scrollTo=PaB4JQVWse9V)
#
# >[Metrics Correlations](#updateTitle=true&folderId=1ItfGk4B7y8TZqsIqknrRk98yg4h93nrI&scrollTo=sczOwo8YifMB)
#
# >[Liner Regresion](#updateTitle=true&folderId=1ItfGk4B7y8TZqsIqknrRk98yg4h93nrI&scrollTo=dJBpDn1IilfY)
#
# >[Logistic regresion](#updateTitle=true&folderId=1ItfGk4B7y8TZqsIqknrRk98yg4h93nrI&scrollTo=3FSdZmxbupwr)
#
# >[Multi-variate logistic regression](#updateTitle=true&folderId=1ItfGk4B7y8TZqsIqknrRk98yg4h93nrI&scrollTo=qJUD3R5lAcZQ)
#
# >[PCA](#updateTitle=true&folderId=1ItfGk4B7y8TZqsIqknrRk98yg4h93nrI&scrollTo=OMlB-NMa8fT6)

# %% [markdown]
# #Prepration

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-3ac32811-6aa7-4e1f-a970-16533317db18" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-3ac32811-6aa7-4e1f-a970-16533317db18">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Apache class logs at test.xlsx to Apache class logs at test.xlsx
# Saving Apache class logs.xlsx to Apache class logs.xlsx
# Saving Free chart  class logs at test.xlsx to Free chart  class logs at test.xlsx
# Saving Free chart class logs.xlsx to Free chart class logs.xlsx
# ...

# %%
import pandas as pd
import numpy as np
import scipy as sp
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt   
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import LogisticRegression
import seaborn as sns
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
sheet_1=pd.read_excel('Apache class logs.xlsx').dropna()
sheet_2=pd.read_excel('Apache class logs at test.xlsx').dropna()
sheet_3=pd.read_excel('Free chart class logs.xlsx').dropna()
sheet_4=pd.read_excel('Free chart  class logs at test.xlsx').dropna()

# %%
print(sheet_1.columns)
print(sheet_2.columns)
print(sheet_3.columns)
print(sheet_4.columns)
# Out:
# Index(['Resource', 'LCOM', 'LCOM*', 'CBO', 'FO', 'DIT', 'NOC', 'LOC', 'NOA',
#        'NOO', 'RFC', 'WMPC'],
#       dtype='object')
# Index(['Ressources', 'HT Effort', 'TNofNewData', 'TNofAssert', 'TLOC',
#        'TINVOK', 'LCOM', 'LCOM*', 'CBO', 'FO', 'DIT', 'NOC', 'LOC', 'NOA',
#        'NOO', 'RFC', 'WMPC'],
#       dtype='object')
# Index(['Resource', 'LCOM', 'LCOM*', 'CBO', 'FO', 'DIT', 'NOC', 'LOC', 'NOA',
#        'NOO', 'RFC', 'WMPC'],
#       dtype='object')
# Index(['Ressources', 'HT Effort', 'TNofNewData', 'TNofAssert', 'TLOC',
#        'TINVOK', 'LCOM', 'LCOM*', 'CBO', 'FO', 'DIT', 'NOC', 'LOC', 'NOA',
#        'NOO', 'RFC', 'WMPC'],
#       dtype='object')

# %% [markdown]
# #Descriptive statistical analysis

# %%
#Apache class metrics log mean
Metrics_mean1=[]
for item in sheet_1.columns[1:]:
  Metrics_mean1.append(sheet_1[item].mean())
Metrics_mean1
# Out:
# [83.85339168490154,
#  62.520787746170676,
#  8.577680525164114,
#  6.2428884026258205,
#  2.4201312910284463,
#  1.676148796498906,
#  125.66301969365426,
#  5.286652078774617,
#  10.61269146608315,
#  64.44857768052516,
#  23.908096280087527]

# %%
#Apache class metrics log at test mean
Metrics_mean2=[]
for item in sheet_2.columns[1:]:
  Metrics_mean2.append(sheet_2[item].mean())
Metrics_mean2
# Out:
# [0.2127659574468085,
#  5.095744680851064,
#  11.26595744680851,
#  82.18085106382979,
#  84.55319148936171,
#  162.5744680851064,
#  68.41489361702128,
#  11.670212765957446,
#  8.851063829787234,
#  2.6914893617021276,
#  0.9680851063829787,
#  180.4787234042553,
#  6.095744680851064,
#  14.24468085106383,
#  84.62765957446808,
#  35.744680851063826]

# %%
#Free chart class metrics log mean
Metrics_mean3=[]
for item in sheet_3.columns[1:]:
  Metrics_mean3.append(sheet_3[item].mean())
Metrics_mean3
# Out:
# [263.4253246753247,
#  55.06818181818182,
#  13.551948051948052,
#  9.0487012987013,
#  2.272727272727273,
#  1.1655844155844155,
#  196.4025974025974,
#  4.928571428571429,
#  15.996753246753247,
#  131.5681818181818,
#  39.98701298701299]

# %%
#Free chart class metrics log at test mean
Metrics_mean4=[]
for item in sheet_4.columns[1:]:
  Metrics_mean4.append(sheet_4[item].mean())
Metrics_mean4
# Out:
# [0.2760416666666667,
#  25.125,
#  19.041666666666668,
#  95.21354166666667,
#  80.58854166666667,
#  399.0729166666667,
#  55.078125,
#  17.28125,
#  11.578125,
#  2.3125,
#  1.28125,
#  259.2395833333333,
#  5.838541666666667,
#  20.03125,
#  153.890625,
#  52.119791666666664]

# %%
#Apache class metrics log standard_dev
Metrics_standard_dev1=[]
for item in sheet_1.columns[1:]:
  Metrics_standard_dev1.append(sheet_1[item].std())
Metrics_standard_dev1
# Out:
# [276.7446221970832,
#  33.01827154044331,
#  7.744195950776802,
#  5.816650213740729,
#  1.30898949250817,
#  14.45865779163853,
#  148.61390357432344,
#  5.650541151246578,
#  10.556286726432294,
#  51.162602878270256,
#  26.685388440798903]

# %%
#Apache class metrics log at test standard_dev
Metrics_standard_dev2=[]
for item in sheet_2.columns[1:]:
  Metrics_standard_dev2.append(sheet_2[item].std())
Metrics_standard_dev2
# Out:
# [0.41145794871387054,
#  8.025589649641562,
#  19.751779847344256,
#  86.76887638401989,
#  11.833628972175426,
#  465.06955172668773,
#  29.28885052442865,
#  8.755199128643557,
#  6.929689044534861,
#  1.3522310973889868,
#  4.963202503369492,
#  157.89085169133497,
#  5.388297053653619,
#  14.267555622650848,
#  62.72297585287112,
#  31.81902324427368]

# %%
#Free chart class metrics log standard_dev
Metrics_standard_dev3=[]
for item in sheet_3.columns[1:]:
  Metrics_standard_dev3.append(sheet_3[item].std())
Metrics_standard_dev3
# Out:
# [1222.6121622540086,
#  33.52181302487944,
#  14.418384124200355,
#  9.833842628830174,
#  1.3639028463338183,
#  5.092165277595482,
#  243.15561214912537,
#  6.504928868266011,
#  20.24966294433342,
#  150.90475854137063,
#  50.170846487803686]

# %%
#Free chart class metrics log at test standard_dev
Metrics_standard_dev4=[]
for item in sheet_4.columns[1:]:
  Metrics_standard_dev4.append(sheet_4[item].std())
Metrics_standard_dev4
# Out:
# [0.4482063828255738,
#  32.23823296834778,
#  22.215704396102495,
#  86.29603998581774,
#  13.337443806300103,
#  1532.7342863526876,
#  33.17712484860458,
#  16.08726407581557,
#  11.110776836522042,
#  1.243306687155107,
#  5.690449655122775,
#  284.187359656103,
#  7.728371201122441,
#  24.186428250535972,
#  152.63885967318362,
#  59.12690428584589]

# %% [markdown]
# #Plotting of sheets' means and standard devs

# %%
# Apache class log mean's plot
x = sheet_1.columns[1:]
y = Metrics_mean1
plt.figure(figsize=(20, 3))
plt.plot(x, y)
plt.title("Apache class log mean's plot")
plt.show()

# %%
# Apache class log at test's mean plot
x = sheet_2.columns[1:]
y = Metrics_mean2
plt.figure(figsize=(20, 3))
plt.plot(x, y)
plt.title("Apache class log at test's mean plot")
plt.show()

# %%
# Free chart class log's mean plot
x = sheet_3.columns[1:]
y = Metrics_mean3
plt.figure(figsize=(20, 3))
plt.plot(x, y)
plt.title("Free chart class log's mean plot")
plt.show()

# %%
# Free chart class  at test's mean plot
x = sheet_4.columns[1:]
y = Metrics_mean4
plt.figure(figsize=(20, 3))
plt.plot(x, y)
plt.title("Free chart class  at test's mean plot")
plt.show()

# %%
# Apache class log standard_dev's plot
x = sheet_1.columns[1:]
y = Metrics_standard_dev1
plt.figure(figsize=(20, 3))
plt.plot(x, y)
plt.title("Apache class log standard_dev's plot")
plt.show()

# %%
# Apache class log at test standard_dev's plot
x = sheet_2.columns[1:]
y = Metrics_standard_dev2
plt.figure(figsize=(20, 3))
plt.plot(x, y)
plt.title("Apache class log at test standard_dev's plot")
plt.show()

# %%
# Free chart class log standard_dev's plot
x = sheet_3.columns[1:]
y = Metrics_standard_dev3
plt.figure(figsize=(20, 3))
plt.plot(x, y)
plt.title("Free chart class log standard_dev's plot")
plt.show()

# %%
# Free chart class log at test standard_dev's plot
x = sheet_4.columns[1:]
y = Metrics_standard_dev4
plt.figure(figsize=(20, 3))
plt.plot(x, y)
plt.title("Free chart class log at test standard_dev's plot")
plt.show()

# %% [markdown]
# #Metrics Correlations

# %%
#Plotting Correlation between Apache classes metrics logs 
Apache_LCOM_corr=[]
for item in sheet_1.columns[1:]:
  Apache_LCOM_corr.append(sheet_1['LCOM'].corr(sheet_1[item]))

x = sheet_1.columns[1:]
y = Apache_LCOM_corr
plt.figure(figsize=(20, 3))
plt.plot(x, y)
plt.title('Plotting Correlation between Apache classes metrics logs ')
plt.show()

# %%
#Plotting Correlation between Apache classes metrics logs at test
Apache_test_LCOM_corr=[]
for item in sheet_2.columns[1:]:
  Apache_test_LCOM_corr.append(sheet_2['LCOM'].corr(sheet_2[item]))

x = sheet_2.columns[1:]
y = Apache_test_LCOM_corr
plt.figure(figsize=(20, 3))
plt.plot(x, y)
plt.title('Plotting Correlation between Apache classes metrics logs at test')
plt.show()

# %%
#Plotting Correlation between Free chart classes metrics logs 
Free_chart_LCOM_corr=[]
for item in sheet_3.columns[1:]:
  Free_chart_LCOM_corr.append(sheet_3['LCOM'].corr(sheet_3[item]))

x = sheet_3.columns[1:]
y = Free_chart_LCOM_corr
plt.figure(figsize=(20, 3))
plt.plot(x, y)
plt.title('Plotting Correlation between Free chart classes metrics logs')
plt.show()

# %%
#Plotting Correlation between Free chart classes metrics logs at test 
Free_chart_test_LCOM_corr=[]
for item in sheet_4.columns[1:]:
  Free_chart_test_LCOM_corr.append(sheet_4['LCOM'].corr(sheet_4[item]))

x = sheet_4.columns[1:]
y = Free_chart_test_LCOM_corr
plt.figure(figsize=(20, 3))
plt.plot(x, y)
plt.title('Plotting Correlation between Free chart classes metrics logs at test')
plt.show()

# %% [markdown]
# #PCA for Free chart class logs at test

# %%
# Free chart class logs at test metrics list
sheet_4.columns
# Out:
# Index(['Ressources', 'HT Effort', 'TNofNewData', 'TNofAssert', 'TLOC',
#        'TINVOK', 'LCOM', 'LCOM*', 'CBO', 'FO', 'DIT', 'NOC', 'LOC', 'NOA',
#        'NOO', 'RFC', 'WMPC'],
#       dtype='object')

# %%
features= ['HT Effort', 'TNofNewData', 'TNofAssert', 'TLOC',
       'TINVOK', 'LCOM', 'LCOM*', 'CBO', 'FO', 'DIT', 'NOC', 'LOC', 'NOA',
       'NOO', 'RFC', 'WMPC']

# %%
X = sheet_4.loc[:, features].dropna()
# %matplotlib inline

# %%
# I used PCA to predict the 'HT Effort' 
target='HT Effort'
y = X.loc[:,[target]].values
X = StandardScaler().fit_transform(X)
pd.DataFrame(data = X, columns = features).head()
# Out:
#    HT Effort  TNofNewData  TNofAssert  ...       NOO       RFC      WMPC
# 0  -0.617491    -0.252689    0.043250  ... -0.084203 -0.662704 -0.256386
# 1  -0.617491    -0.439290   -0.272666  ... -0.457285 -0.682410 -0.527698
# 2  -0.617491    -0.501490   -0.182404  ... -0.167110 -0.774369 -0.442913
# 3  -0.617491     0.369314   -0.137273  ... -0.581646 -0.708684 -0.493784
# 4  -0.617491    -0.252689   -0.543451  ... -0.664553 -0.787506 -0.629440
#
# [5 rows x 16 columns]

# %%
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(X)
principalDf = pd.DataFrame(data = principalComponents
             , columns = ['principal component 1', 'principal component 2'])
principalDf.head(5)
# Out:
#    principal component 1  principal component 2
# 0              -0.497497               0.140629
# 1              -1.360668              -0.000088
# 2              -1.476907               0.081516
# 3              -0.915874               0.360939
# 4              -1.822410               0.271465

# %%
sheet=sheet_4.dropna()
finalDf = pd.concat([principalDf.reset_index(), sheet[[target]].reset_index()], axis = 1)
finalDf
# Out:
#      index  principal component 1  principal component 2  index  HT Effort
# 0        0              -0.497497               0.140629      0          0
# 1        1              -1.360668              -0.000088      1          0
# 2        2              -1.476907               0.081516      2          0
# 3        3              -0.915874               0.360939      3          0
# 4        4              -1.822410               0.271465      4          0
# ..     ...                    ...                    ...    ...        ...
# 187    187              -1.497574               1.821362    224          1
# 188    188              -1.998503               0.352038    225          0
# 189    189              -2.280985               0.699794    227          0
# 190    190              -0.855288              -0.797355    228          0
# 191    191               0.895671               2.462411    229          1
#
# [192 rows x 5 columns]

# %%
# preparing samples from the whole 'HT Effort' value's range
Low = sheet['HT Effort'].min()
Mean = sheet['HT Effort'].mean()
High = sheet['HT Effort'].max()

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 Component PCA', fontsize = 20)


targets = [Low, Mean, High]
colors = ['r', 'g', 'b']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['HT Effort'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
               , finalDf.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %% [markdown]
# #Liner Regresion

# %%
X = sheet_1['LCOM'].values.reshape(-1, 1)
Y= sheet_1['NOO'].values.reshape(-1, 1)
scaler = MinMaxScaler()
scaler.fit(X)
X=scaler.transform(X)
scaler = MinMaxScaler()
scaler.fit(Y)
Y=scaler.transform(Y)

# %%
linear_regressor = LinearRegression() 
linear_regressor.fit( X, Y )  
Y_pred = linear_regressor.predict(X)

# %%
plt.scatter(X, Y)
plt.plot(X, Y_pred, color='red')
plt.show()

# %% [markdown]
# #Logistic regresion

# %%
X = sheet_1['LCOM'].values.reshape(-1, 1)
Y= sheet_1['NOO'].values.reshape(-1, 1)
X=X.astype(int)/10
Y=Y.astype(int)/10
X=X.astype(int)
Y=Y.astype(int)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=0)

# %%
logisticRegr = LogisticRegression()
logisticRegr.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
# ...

# %%
predictions = logisticRegr.predict(x_test)

# %%
score = logisticRegr.score(x_test, y_test)
print(score)
# Out:
# 0.8434782608695652

# %%
cm = metrics.confusion_matrix(y_test, predictions)
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(score)
plt.title(all_sample_title, size = 15);
plt.savefig('toy_Digits_ConfusionSeabornCodementor.png')
plt.show()

# %% [markdown]
# #Multi-variate logistic regression

# %%
sheet_1.columns
# Out:
# Index(['Resource', 'LCOM', 'LCOM*', 'CBO', 'FO', 'DIT', 'NOC', 'LOC', 'NOA',
#        'NOO', 'RFC', 'WMPC'],
#       dtype='object')

# %%
X = sheet_1.drop(['Resource', 'NOO'], axis=1)
Y= sheet_1['NOO'].values.reshape(-1, 1)
X=X.astype(int)/10
Y=Y.astype(int)/10
X=X.astype(int)
Y=Y.astype(int)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.25, random_state=0)

# %%
logisticRegr = LogisticRegression()
logisticRegr.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:760: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /usr/local/lib/python3.7/dist-packages/sklearn/linear_model/_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
# ...

# %%
predictions = logisticRegr.predict(x_test)

# %%
score = logisticRegr.score(x_test, y_test)
print(score)
# Out:
# 0.8434782608695652

# %%
cm = metrics.confusion_matrix(y_test, predictions)
plt.figure(figsize=(9,9))
sns.heatmap(cm, annot=True, fmt=".3f", linewidths=.5, square = True, cmap = 'Blues_r');
plt.ylabel('Actual label');
plt.xlabel('Predicted label');
all_sample_title = 'Accuracy Score: {0}'.format(score)
plt.title(all_sample_title, size = 15);
plt.savefig('toy_Digits_ConfusionSeabornCodementor.png')
plt.show()

# %%
plt.plot(np.arange(sheet_1['NOO'].values.shape[0]), sheet_1['NOO'].values)
